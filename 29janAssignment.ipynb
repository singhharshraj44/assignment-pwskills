# %%
 Q1. Who developed Python Programming Language?
Ans- Python was created by Guido van Rossum, and first released on February 20, 1991.

Q2. Which type of programming does Python support?
Ans- Python is an interpreted programming language, supporting object-oriented, structured, and functional programming.

Q3. Is Python case sensitive when dealing with identifiers?
Ans- Yes Python is case sensitive when dealing with identifiers.

Q4. What is the correct extension of the Python file?
Ans- The correct extension of the Python file is “.py”.

Q5. Is Python code compiled or interpreted?
Ans- Python is both compiled and interpreted.

Q6. Name a few blocks of code used to define in Python language.
Ans- If-Else
          For loops
          While loops
Q7. State a character used to give single line comments in Python.
Ans- #

Q8. Mention functions which can help us to find the version of Python that we are currently working on?
Ans- a) sys.version
         b)platform.python_version()
        c) platform.python_implementation()

Q9. Python supports the creation of anonymous functions at runtime, using a construct called?
Ans- Python supports the creation of anonymous functions at runtime using a construct called 'lambda'.

Q10. What does pip stand for Python?
Ans- PIP stands for Precise Infectious Packages.

Q11. Mention a few built-in functions in Python?
Ans-
•	Python set function.
•	Python sorted function.
•	Python reversed function.
•	Python all function
•	Python range function
•	Python object function
•	Python type function
•	Python character function
•	Python next function
•	Python input function

Q12. What is the maximum possible length of an identifier in Python?
Ans- There is no specific limit on length of an identifier in Python.

Q13. What are the benefits of using Python?
Ans- Python is a very popular high level programming language which is widely used in a variety of domains including data science and machine learning. It is open-source language and free that means code is freely available for anyone to use and modify. Pythons is also cross platform compatible that means we can use python in Mac, Windows, and Linux.

Q14. How is memory managed in Python?
Ans- Memory is managed in Python by Python interpreter through a mechanism called as reference counting. Every object in Python has a reference count that keeps track of the number of references to that object, when an object’s reference count reaches zero, it is no longer accessible, and its memory is freed up.

Q15. How to install Python on Windows and set path variables?
1.	Ans- Go to the official Python website and download the latest version of Python for Windows. Choose the appropriate version for your system (32-bit or 64-bit).
2.	Run the downloaded installer and follow the installation prompts. During the installation process, make sure to select the "Add Python to PATH" option.
3.	After the installation is complete, open the Windows Command Prompt by pressing the "Windows key" + "R" and typing "cmd" in the Run dialog box.
4.	Type the command "python" and press "Enter". If Python is installed correctly, you should see the Python version number and the Python prompt ">>>".
5.	To set the path variables, right-click on the "This PC" icon on the desktop and select "Properties".
6.	Click on "Advanced System Settings" and then click on the "Environment Variables" button.
7.	In the "System Variables" section, scroll down and find the "Path" variable, then click "Edit".
8.	Add the path to the Python installation folder at the end of the existing list of paths. For example, if Python is installed in the "C:\Python" folder, add ";C:\Python" to the end of the existing path.
9.	Click "OK" to save the changes and close all the windows.
10.	Open a new Command Prompt window and type the command "python" again. If Python is correctly installed and the path variables are set up correctly, the Python interpreter should start.


Q16. Is indentation required in Python?
Ans- Yes, indentation is required in Python. Unlike many other programming languages that use brackets or other symbols to delimit blocks of code, Python uses indentation to group statements into blocks. The amount of indentation indicates the level of nesting in the code.
